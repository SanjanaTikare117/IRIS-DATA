# %% [markdown]
# <a href="https://colab.research.google.com/github/SanjanaTikare117/IRIS-DATA/blob/main/seta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
from google.colab import drive

# %%
df = pd.read_csv("/content/iris.csv")
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
iris_series = pd.isnull(data["Iris"])
data[iris_series]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-0fd67608c572> in <cell line: 4>()
#       2 import matplotlib.pyplot as plt
#       3 import seaborn as sns
# ----> 4 iris_series = pd.isnull(data["Iris"])
#       5 data[iris_series]
#
# NameError: name 'data' is not defined

# %%
# Making a list of missing value types
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
missing_values = ["sepal length,sepal wide"]
df = pd.read_csv("iris_data.csv", df_values = missing_values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-2d3e439bd888> in <cell line: 6>()
#       4 import seaborn as sns
#       5 missing_values = ["sepal length,sepal wide"]
# ----> 6 df = pd.read_csv("iris_data.csv", df_values = missing_values)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df.dropna()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

iris = datasets.load_iris()
X = iris.data
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1, stratify=y)

mmsscaler = MinMaxScaler()
X_train_norm = mms.fit_transform(X_train)
X_test_norm = mms.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-0389bce35000> in <cell line: 12>()
#      10
#      11 minscaler = MinMaxScaler()
# ---> 12 X_train_norm = mms.fit_transform(X_train)
#      13 X_test_norm = mms.transform(X_test)
#      14
#
# NameError: name 'mms' is not defined

# %%
def standardize(values):
    return (values - values.mean())/values.std()

# %%
from sklearn.preprocessing import StandardScaler
data = [[1, 2], [3, 4], [0, 10], [11, 8]]
scaler = StandardScaler()
model = scaler.fit(data)
scaled_data = model.transform(data)
print(scaled_data)
# Out:
# [[ 0.97596444 -1.61155897]
#  [-0.66776515  0.08481889]
#  [-1.28416374  1.10264561]
#  [ 0.97596444  0.42409446]]

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

iris = datasets.load_iris()
X = iris.data
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1, stratify=y)

sc = StandardScaler()
X_train_norm = sc.fit_transform(X_train)
X_test_norm = sc.transform(X_test)

# %%
import matplotlib.pyplot as plt
import pandas as pd
from google.colab import drive

# %%
df = pd.read_csv("/content/tips 2.csv")
df.head()
# Out:
#    Total_bill   Tip     Sex Smoker  Day    Time  Size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
tips = sns.load_dataset("tips")
sns.regplot(x="total_bill", y="tip", data=tips);

# %%
sns.lmplot(x="total_bill", y="tip", data=tips);

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
statistics.mean(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-0de815ecd4e7> in <cell line: 1>()
# ----> 1 statistics.mean(data)
#
# NameError: name 'statistics' is not defined

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline
df = pd.read_csv("tips.csv")
df.head()
# Out:
# UsageError: Line magic function `%` not found.

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips);

# %%
sns.boxplot(x="total_bill", y="tip", hue="smoker", data=tips);

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
